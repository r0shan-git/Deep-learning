# %%
# ===============================
# Imports
# ===============================
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


# ===============================
# Generate Data
# ===============================

X_train = np.linspace(-1, 1, 20)

y_train = np.array([
    -0.6561, -0.3099, -0.59035, -0.50855, -0.285,
    -0.2443, -0.02445, 0.00135, -0.2006, 0.07475,
    -0.1422, 0.06515, 0.15265, 0.3521, 0.28415,
    0.5524, 0.23115, 0.20835, 0.4211, 0.60485
])

X_test = np.linspace(-1, 1, 20)

y_test = np.array([
    -0.69415, -0.451, -0.43005, -0.4484, -0.1475,
    -0.5019, -0.28055, 0.24595, -0.21425, -0.0286,
    0.23415, 0.46575, 0.07955, 0.1973, 0.0719,
    0.3639, 0.5536, 0.3365, 0.50705, 0.33435
])


# ===============================
# Plot Data
# ===============================

plt.scatter(X_train, y_train, c="red", label="Train")
plt.scatter(X_test, y_test, c="blue", label="Test")
plt.legend()
plt.show()


# ===============================
# Regression Model (Without Dropout)
# ===============================

model_1 = Sequential()

model_1.add(Dense(128, input_dim=1, activation="relu"))
model_1.add(Dense(128, activation="relu"))
model_1.add(Dense(1, activation="linear"))

adam = Adam(learning_rate=0.01)

model_1.compile(
    loss="mse",
    optimizer=adam,
    metrics=["mse"]
)

model_1.fit(
    X_train,
    y_train,
    epochs=500,
    validation_data=(X_test, y_test),
    verbose=0
)


# ===============================
# Evaluate Model 1
# ===============================

_, train_mse_1 = model_1.evaluate(X_train, y_train, verbose=0)
_, test_mse_1 = model_1.evaluate(X_test, y_test, verbose=0)

print("Model 1 (No Dropout)")
print("Train MSE:", train_mse_1)
print("Test  MSE:", test_mse_1)


# ===============================
# Prediction Model 1
# ===============================

y_pred_1 = model_1.predict(X_test)

plt.figure()
plt.scatter(X_train, y_train, c="red", label="Train")
plt.scatter(X_test, y_test, c="blue", label="Test")
plt.plot(X_test, y_pred_1, label="Prediction")
plt.legend()
plt.ylim((-1.5, 1.5))
plt.show()


# ===============================
# Dropout Model
# ===============================

model_2 = Sequential()

model_2.add(Dense(128, input_dim=1, activation="relu"))
model_2.add(Dropout(0.2))

model_2.add(Dense(128, activation="relu"))
model_2.add(Dropout(0.2))

model_2.add(Dense(1, activation="linear"))

model_2.compile(
    loss="mse",
    optimizer=adam,
    metrics=["mse"]
)

model_2.fit(
    X_train,
    y_train,
    epochs=500,
    validation_data=(X_test, y_test),
    verbose=0
)


# ===============================
# Evaluate Model 2
# ===============================

_, train_mse_2 = model_2.evaluate(X_train, y_train, verbose=0)
_, test_mse_2 = model_2.evaluate(X_test, y_test, verbose=0)

print("\nModel 2 (With Dropout)")
print("Train MSE:", train_mse_2)
print("Test  MSE:", test_mse_2)


# ===============================
# Prediction Model 2
# ===============================

y_pred_2 = model_2.predict(X_test)

plt.figure()
plt.scatter(X_train, y_train, c="red", label="Train")
plt.scatter(X_test, y_test, c="blue", label="Test")
plt.plot(X_test, y_pred_2, label="Prediction")
plt.legend()
plt.ylim((-1.5, 1.5))
plt.show()
# Out:
# c:\Users\rosha\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# c:\Users\rosha\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model 1 (No Dropout)
# Train MSE: 0.00453648017719388
# Test  MSE: 0.046339429914951324
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 120
#     112 model_2.add(Dense(1, activation="linear"))
#     114 model_2.compile(
#     115     loss="mse",
#     116     optimizer=adam,
#     117     metrics=["mse"]
#     118 )
# --> 120 model_2.fit(
#     121     X_train,
#     122     y_train,
#     123     epochs=500,
#     124     validation_data=(X_test, y_test),
#     125     verbose=0
#     126 )
#     129 # ===============================
#     130 # Evaluate Model 2
#     131 # ===============================
#     133 _, train_mse_2 = model_2.evaluate(X_train, y_train, verbose=0)
#
# File c:\Users\rosha\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\rosha\anaconda3\Lib\site-packages\keras\src\optimizers\base_optimizer.py:408, in BaseOptimizer._check_variables_are_known(self, variables)
#     406 for v in variables:
#     407     if self._var_key(v) not in self._trainable_variables_indices:
# --> 408         raise ValueError(
#     409             f"Unknown variable: {v}. This optimizer can only "
#     410             "be called for the variables it was originally built with. "
#     411             "When working with a new set of variables, you should "
#     412             "recreate a new optimizer instance."
#     413         )
#
# ValueError: Unknown variable: <Variable path=sequential_1/dense_3/kernel, shape=(1, 128), dtype=float32>. This optimizer can only be called for the variables it was originally built with. When working with a new set of variables, you should recreate a new optimizer instance.

# %%
import tensorflow as tf  # for neural network
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
pip install --upgrade pip setuptools wheel
# Out:
#   Cell In[1], line 1
#     pip install --upgrade pip setuptools wheel
#         ^
# SyntaxError: invalid syntax

# %%
# ===============================
# Generate Data
# ===============================

X_train = np.linspace(-1, 1, 20)

y_train = np.array([
    -0.6561, -0.3099, -0.59035, -0.50855, -0.285,
    -0.2443, -0.02445, 0.00135, -0.2006, 0.07475,
    -0.1422, 0.06515, 0.15265, 0.3521, 0.28415,
    0.5524, 0.23115, 0.20835, 0.4211, 0.60485
])
