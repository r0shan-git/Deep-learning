# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding ,SimpleRNN,Dense,LSTM,GRU

# %%
# load the IMDB dataset 
(x_train,y_train),(x_test,y_test)=imdb.load_data(num_words=10000)

# Pad sequeces to have the same length
x_train=pad_sequences(x_train,maxlen=100)
x_test=pad_sequences(x_test,maxlen=100)
# Out:
# ...
# 17464789/17464789 [==============================] - 8s 0us/step

# %%
# define the RNN model
model=Sequential([Embedding(10000,32,input_length=100),#embedding layer to convert words to vectors
SimpleRNN(5,return_sequences=True),  # RNN layers with 5 units
SimpleRNN(5),                       # Another RNN layer with 5 units
Dense(1,activation='sigmoid')])    # Output layer for binary classification

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 100, 32)           320000
#
#  simple_rnn (SimpleRNN)      (None, 100, 5)            190
#
#  simple_rnn_1 (SimpleRNN)    (None, 5)                 55
#
#  dense (Dense)               (None, 1)                 6
#
# ...
# Total params: 320,251
# Trainable params: 320,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define the LSTM model
model=Sequential([Embedding(10000,32,input_length=100),#embedding layer to convert words to vectors
LSTM(5,return_sequences=True),  # RNN layers with 5 units
LSTM(5),                       # Another RNN layer with 5 units
Dense(1,activation='sigmoid')])    # Output layer for binary classification
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_4 (Embedding)     (None, 100, 32)           320000
#
#  lstm_2 (LSTM)               (None, 100, 5)            760
#
#  lstm_3 (LSTM)               (None, 5)                 220
#
#  dense_3 (Dense)             (None, 1)                 6
#
# ...
# Total params: 320,986
# Trainable params: 320,986
# Non-trainable params: 0
# _________________________________________________________________

# %%
# DEfine the GRU model
model=Sequential([Embedding(10000,32,input_length=100),#embedding layer to convert words to vectors
GRU(5,return_sequences=True),  # RNN layers with 5 units
GRU(5),                       # Another RNN layer with 5 units
Dense(1,activation='sigmoid')])    # Output layer for binary classification

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_5 (Embedding)     (None, 100, 32)           320000
#
#  gru_2 (GRU)                 (None, 100, 5)            585
#
#  gru_3 (GRU)                 (None, 5)                 180
#
#  dense_4 (Dense)             (None, 1)                 6
#
# ...
# Total params: 320,771
# Trainable params: 320,771
# Non-trainable params: 0
# _________________________________________________________________
